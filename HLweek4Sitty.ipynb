# %%
pip install pandas
# Out:
# ...
# WARNING: You are using pip version 20.2.3; however, version 21.1.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
bestdest = pd.read_csv("PandasTask1.csv")

print( bestdest)
# Out:
#      Destination  F_back_Score  Hotel_Rating  All_Inc_Hotels     Popular_City
# 0       Tanzania             9             4              10         Zanzibar
# 1       Maldives             9             5              25             Male
# 2         Hawaai             6             4              43             Maui
# 3   South Africa             8             5              20        Cape Town
# 4         Tahiti             9             3               5        Bora Bora
# 5         Greece             5             3              13        Santorini
# 6         Mexico             8             2               7           Cancun
# 7        Bahamas             9             4              54  Paradise Island
# 8       Barbados             8             3              48       Bridgetown
# 9       Zimbabwe             9             5              35   Victoria Falls
# 10        France             4             5              10        St Tropez
# ...

# %%
# 1. How many rows and columns are there in your file?

# %%
data = pd.read_csv("PandasTask1.csv")

data.shape
# Out:
# (15, 5)

# %%
# 2. Print row 3-8 ( using iloc loc

# %%
data.iloc[2:8]
# Out:
#     Destination  F_back_Score  Hotel_Rating  All_Inc_Hotels     Popular_City
# 2        Hawaai             6             4              43             Maui
# 3  South Africa             8             5              20        Cape Town
# 4        Tahiti             9             3               5        Bora Bora
# 5        Greece             5             3              13        Santorini
# 6        Mexico             8             2               7           Cancun
# 7       Bahamas             9             4              54  Paradise Island

# %%
# 3. Find the mean number of all inclusive hotels across all destinations.

# %%
data["All_Inc_Hotels"].mean()
# Out:
# 32.93333333333333

# %%
# 4.Find the lowest scoring destination.

# %%
data['F_back_Score'].min(axis=0)
# Out:
# 4

# %%
#5. Find the highest scoring destination.

# %%
data['F_back_Score']. max(axis=0)
# Out:
# 10

# %%
# 6. Find all the destinations where there are more than 9 all inclusive hotels.

# %%
data[(data.All_Inc_Hotels > 9)]
# Out:
#      Destination  F_back_Score  Hotel_Rating  All_Inc_Hotels     Popular_City
# 0       Tanzania             9             4              10         Zanzibar
# 1       Maldives             9             5              25             Male
# 2         Hawaai             6             4              43             Maui
# 3   South Africa             8             5              20        Cape Town
# 5         Greece             5             3              13        Santorini
# 7        Bahamas             9             4              54  Paradise Island
# 8       Barbados             8             3              48       Bridgetown
# 9       Zimbabwe             9             5              35   Victoria Falls
# 10        France             4             5              10        St Tropez
# 11         Japan             7             4              32          Okinawa
# 12     Australia             7             2              50       Gold Coast
# ...

# %%
# 7. Filter the data by score above 8.

# %%
data[(data.F_back_Score > 8)]
# Out:
#    Destination  F_back_Score  Hotel_Rating  All_Inc_Hotels     Popular_City
# 0     Tanzania             9             4              10         Zanzibar
# 1     Maldives             9             5              25             Male
# 4       Tahiti             9             3               5        Bora Bora
# 7      Bahamas             9             4              54  Paradise Island
# 9     Zimbabwe             9             5              35   Victoria Falls
# 13      Israel            10             5              77        Jerusalem

# %%
filter_a = data["F_back_Score"] > 8

filter_a
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7      True
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13     True
# 14    False
# Name: F_back_Score, dtype: bool

# %%
# 8. Filter the data score below 2 ( I need to know if these destinations should be removed or there is a problem)

# %%
filter_b = data["F_back_Score"] < 2

filter_b
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# Name: F_back_Score, dtype: bool

# %%
#9 Is there a correlation between number of all inclusive hotels and score?

# %%
df = pd.read_csv("PandasTask1.csv")
df.plot.scatter(x='All_Inc_Hotels', y='F_back_Score')
# Out:
# <AxesSubplot:xlabel='All_Inc_Hotels', ylabel='F_back_Score'>

# %%
df.groupby('Destination').mean().plot.bar('F_back_Score')
# Out:
# <AxesSubplot:xlabel='F_back_Score'>

# %%
#10. Create a data visualisation diagram to show destination and highest scores

# %%
df.groupby('Destination').mean().plot.bar(y='F_back_Score')
# Out:
# <AxesSubplot:xlabel='Destination'>
